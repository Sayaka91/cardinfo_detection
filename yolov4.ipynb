# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayaka91/YOLOv4/blob/main/yolov4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DeepLearning/darknet
# !rm darknet
# !make
# Out:
# /content/drive/MyDrive/DeepLearning/darknet
# chmod +x *.sh
# ...

# %%
# %cd /content/drive/MyDrive/DeepLearning/darknet
# !./darknet detector train yolo.data cfg/yolov4-custom.cfg yolov4.conv.137 -dont_show
# Out:
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.291487, GIOU: 0.235647), Class: 0.477173, Obj: 0.431801, No Obj: 0.474526, .5R: 0.153846, .75R: 0.000000, count: 13, class_loss = 2547.552490, iou_loss = 2.459717, total_loss = 2550.012207
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.304118, GIOU: 0.078392), Class: 0.470484, Obj: 0.485335, No Obj: 0.498226, .5R: 0.034483, .75R: 0.000000, count: 29, class_loss = 716.025635, iou_loss = 1.782349, total_loss = 717.807983
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.172926, GIOU: -0.113701), Class: 0.437349, Obj: 0.415727, No Obj: 0.482638, .5R: 0.000000, .75R: 0.000000, count: 18, class_loss = 173.121124, iou_loss = 0.054703, total_loss = 173.175827
#  total_bbox = 110582, rewritten_bbox = 0.007234 %
# ...
